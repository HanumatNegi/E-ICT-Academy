# %% [markdown]
# <a href="https://colab.research.google.com/github/HanumatNegi/E-ICT-Academy/blob/main/First.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("3000")
# Out:
# 3000

# %%
print(300)
# Out:
# 300

# %%
print("My name is HAanumat")
# Out:
# My name is HAanumat

# %%
print(3-5)
# Out:
# -2

# %%
print(300)
# Out:
# 300

# %%
print("My name is Hanumat")
# Out:
# My name is Hanumat
