# %% [markdown]
# <a href="https://colab.research.google.com/github/HanumatNegi/E-ICT-Academy/blob/main/Class-Programs/First.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("3000")
# Out:
# 3000

# %%
print(300)
# Out:
# 300

# %%
print("My name is HAanumat")
# Out:
# My name is HAanumat

# %%
print(3-5)
# Out:
# -2

# %%
print(300)
# Out:
# 300

# %%
print("My name is Hanumat")
# Out:
# My name is Hanumat

# %%
print(1+3>2)
# Out:
# True

# %%
print("10>9")
# Out:
# 10>9

# %% [markdown]
# In order to check for the "Type" of the data then we use "type()" function.

# %%
#For example
x=4.5
print(type(x))
print("next example")
type(True)
# Out:
# <class 'float'>
# next example
# bool

# %% [markdown]
# **Variables**:
#
# --Containers to keep objects
#
# --these are identifiers/names given to objects
#
# --it refers to the reserved memory location
#
# For example
#
# X=3
#
# Here 3 is being assigned a variable X
#
# *Variable can be combination of A-Z,a-z,0-9,_&-, but can never start with _,-or 0-9

# %%
a=3
print(a)
type(a)
b=4.5
print(b)
type(b)
print(a*b)
# Out:
# 3
# 4.5
# 13.5

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
X=3
X=5
print(X)
# Out:
# 5

# %%
x="i am"
y="legend"
print(x)
print(y)
print(x+y)
print(x,y)
# Out:
# i am
# legend
# i amlegend
# i am legend

# %%
x=10
y=x
print(y)
# Out:
# 10

# %%
x=10
y=x
print(y)
x= 15
y=x
print(y)
# Out:
# 10
# 15

# %%
x=10
y=10
z=20
y=x
print(y)
x=15
y=z
print(x,y,z)
# Out:
# 10
# 15 20 20

# %%
name=input();
print("Welcome "+name)
# Out:
# Hanumat
# Welcome Hanumat
